# %% [markdown]
# # **Introductions**

# %% [markdown]
# ## 1. Prerequisites and how to succeed in this course
#
# * LLM architecture, training, and mechanisms are advanced topics
# * Take notes.
# * Do excercises.

# %% [markdown]
# #### Helpful but not necessary
# * Python coding experience (PyTorch)
# * Linear algebra (vector spaces, matrix operations)
# * Machine learning (cosine similarity, clustering)
# * Statistics (regression, t-test)
# * Deep learning (gradient descent, model architectures, training)

# %% [markdown]
# ## 2. Using the Udemy platform

# %% [markdown]
# ## 3. Getting the course code, and the detailed overview
#
# [Link to GitHub repository page  ](https://github.com/mikexcohen/LLM_course)
#
# [Direct link to zip download (all code files)](https://github.com/mikexcohen/LLM_course/archive/refs/heads/main.zip)
#
# [Spreadsheet with lecture titles, code filenames, and key take-home points](https://docs.google.com/spreadsheets/d/1jTwXQJBh2aGFdazuVsnS98dcwwjGWL1Uw__U5fOuhEE/edit?usp=sharing)

# %% [markdown]
# ## 4. Do you need a Colab Pro subscription?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 5. About the "CodeChallenge" videos
#
# * Pause the video and solve the code challenge.
# * Code from scratch or copy/paste code.
# * Start from the helper files.
# * Watch solutions, then code yourself.
# * Watch solutions for deeper discussions about theory and implementations.

# %% [markdown]
# #### \*helper.ipynb vs solutions/*.ipynb
# * In each section there are demo files and \*helper.ipynb files and subfolder /solutions.
# * Helper files are incomplete files.
# * Solutions subfolder complete files.
